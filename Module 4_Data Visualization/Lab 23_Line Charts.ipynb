# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Line Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on using line charts to analyze trends over time and across different categories in a dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Track trends in compensation across age groups and specific age ranges.
#
# - Analyze job satisfaction trends based on experience level.
#
# - Explore and interpret line charts to identify patterns and trends.

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %% [markdown]
# #### Step 1: Download the dataset

# %%
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Out:
# --2025-05-30 05:57:15--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  50.4MB/s    in 3.0s
#
# 2025-05-30 05:57:18 (50.4 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]

# %% [markdown]
# #### Step 2: Import necessary libraries and load the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the data

# %%
df = pd.read_csv("survey-data.csv")

# %% [markdown]
# #### Display the first few rows to understand the structure of the data

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Trends in Compensation Over Age Groups

# %% [markdown]
# ##### 1. Line Chart of Median `ConvertedCompYearly` by Age Group

# %% [markdown]
# - Track how the median yearly compensation (ConvertedCompYearly) changes across different age groups.
#
# - Use a line chart to visualize these trends.

# %%
## Write your code here
df_ConvertedCompYearly_Age=df[['ConvertedCompYearly','Age']].copy()
#To visualize age in order
from pandas.api.types import CategoricalDtype
AgeLabels = ['Under 18 years old','18-24 years old', '25-34 years old','35-44 years old','45-54 years old',
             '55-64 years old','65 years or older','Prefer not to say']
Age_ordered = CategoricalDtype(categories = AgeLabels, ordered = True)
df_ConvertedCompYearly_Age['Age'] = df_ConvertedCompYearly_Age['Age'].astype(Age_ordered)
df_line=df_ConvertedCompYearly_Age.groupby('Age')['ConvertedCompYearly'].median()
df_line.plot(x='Age',y='ConvertedCompYearly')
plt.xticks(rotation=85)
# Out:
# /tmp/ipykernel_299/4117388436.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_line=df_ConvertedCompYearly_Age.groupby('Age')['ConvertedCompYearly'].median()
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.]),
#  [Text(-1.0, 0, 'Prefer not to say'),
#   Text(0.0, 0, 'Under 18 years old'),
#   Text(1.0, 0, '18-24 years old'),
#   Text(2.0, 0, '25-34 years old'),
#   Text(3.0, 0, '35-44 years old'),
#   Text(4.0, 0, '45-54 years old'),
#   Text(5.0, 0, '55-64 years old'),
#   Text(6.0, 0, '65 years or older'),
#   Text(7.0, 0, 'Prefer not to say'),
#   Text(8.0, 0, '')])

# %% [markdown]
# ##### 2. Line Chart of Median `ConvertedCompYearly` for Ages 25 to 45

# %% [markdown]
# For a closer look, plot a line chart focusing on the median compensation for respondents between ages 25 and 45.

# %%
## Write your code here
df_ConvertedCompYearly_Age=df[['ConvertedCompYearly','Age']].copy()
#df_ConvertedCompYearly_Age=df_ConvertedCompYearly_Age.dropna(subset=['ConvertedCompYearly','Age'])
df_ConvertedCompYearly_Age['Age'] = df_ConvertedCompYearly_Age['Age'].astype(Age_ordered)
df_filtered=df[(df_ConvertedCompYearly_Age['Age']=='25-34 years old')|(df_ConvertedCompYearly_Age['Age']=='35-44 years old')]
AgeMap = {    '25-34 years old':25,
              '35-44 years old':44,
         }
df_filtered['AgeNumeric'] = df_filtered['Age'].map(AgeMap)
df_line=df_filtered.groupby('AgeNumeric')['ConvertedCompYearly'].median()
df_line.plot(x='AgeNumeric',y='ConvertedCompYearly')
#df_line.xlim
# Out:
# /tmp/ipykernel_299/2557929914.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['AgeNumeric'] = df_filtered['Age'].map(AgeMap)
# <Axes: xlabel='AgeNumeric'>

# %% [markdown]
# ### Task 2: Trends in Job Satisfaction by Experience Level

# %% [markdown]
# ##### 1. Line Chart of Job Satisfaction (`JobSatPoints_6`) by Experience Level

# %% [markdown]
# - Use a column that approximates experience level to analyze how job satisfaction changes with experience.
#
# - If needed, substitute an available experience-related column for `Experience`.

# %%
## Write your code here
df_Experience_JobSat=df[['YearsCode','JobSatPoints_6']]
df_Experience_JobSat=df_Experience_JobSat.dropna(subset=['YearsCode','JobSatPoints_6'])
df_Experience_JobSat['YearsCode']=df_Experience_JobSat['YearsCode'].replace('Less than 1 year',0)
df_Experience_JobSat['YearsCode']=df_Experience_JobSat['YearsCode'].replace('More than 50 years',51)
df_Experience_JobSat['YearsCode']=df_Experience_JobSat['YearsCode'].astype(int)
#df_Experience_JobSat=df_Experience_JobSat.sort_values(by='YearsCode')
df_line=df_Experience_JobSat.groupby('YearsCode')['JobSatPoints_6'].median()
df_line.plot(x='YearsCode',y='JobSatPoints_6')
# Out:
# <Axes: xlabel='YearsCode'>

# %% [markdown]
# ### Task 3: Trends in Job Satisfaction and Compensation by Experience

# %% [markdown]
# ##### 1.Line Chart of Median ConvertedCompYearly Over Experience Level
#
# - This line chart will track how median compensation (`ConvertedCompYearly`) changes with increasing experience.
#
# - Use a column such as `WorkExp` or another relevant experience-related column.

# %%
## Write your code here
df_Experience_ConvertedCompYearly=df[['YearsCode','ConvertedCompYearly']].copy()
df_Experience_ConvertedCompYearly=df_Experience_ConvertedCompYearly.dropna(subset=['YearsCode','ConvertedCompYearly'])
df_Experience_ConvertedCompYearly['YearsCode']=df_Experience_JobSat['YearsCode'].astype(int)
#df_Experience_JobSat=df_Experience_JobSat.sort_values(by='YearsCode')
df_line=df_Experience_ConvertedCompYearly.groupby('YearsCode')['ConvertedCompYearly'].median()
df_line.plot(x='YearsCode',y='ConvertedCompYearly')
# Out:
# <Axes: xlabel='YearsCode'>

# %% [markdown]
# ##### 2.Line Chart of Job Satisfaction (`JobSatPoints_6`) Across Experience Levels
#
# - Create a line chart to explore trends in job satisfaction (`JobSatPoints_6`) based on experience level.
#
# - This chart will provide insight into how satisfaction correlates with experience over time

# %%
## Write your code here
df_Experience_JobSat=df[['YearsCodePro','JobSatPoints_6']]
df_Experience_JobSat=df_Experience_JobSat.dropna(subset=['YearsCodePro','JobSatPoints_6'])
df_Experience_JobSat['YearsCodePro']=df_Experience_JobSat['YearsCodePro'].replace('Less than 1 year',0)
df_Experience_JobSat['YearsCodePro']=df_Experience_JobSat['YearsCodePro'].replace('More than 50 years',51)
df_Experience_JobSat['YearsCodePro']=df_Experience_JobSat['YearsCodePro'].astype(int)
#df_Experience_JobSat=df_Experience_JobSat.sort_values(by='YearsCodePro')
df_line=df_Experience_JobSat.groupby('YearsCodePro')['JobSatPoints_6'].median()
df_line.plot(x='YearsCodePro',y='JobSatPoints_6')
# Out:
# <Axes: xlabel='YearsCodePro'>

# %% [markdown]
# #### Final Step: Review

# %% [markdown]
# In this lab, you focused on analyzing trends in compensation and job satisfaction, specifically exploring how these metrics change with age and experience levels using line charts.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you explored essential data visualization techniques with a focus on analyzing trends using line charts. You learned to:
#
# - Visualize the distribution of compensation across age groups to understand salary trends.
#
# - Track changes in median compensation over various experience levels, identifying how earnings progress with experience.
#
# - Examine trends in job satisfaction by experience, revealing how satisfaction varies throughout a developer's career.
#
# These analyses allow for a deeper understanding of how factors like age and experience influence job satisfaction and compensation. By using line charts, you gained insights into continuous data patterns, which are invaluable for interpreting professional trends in the developer community.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
